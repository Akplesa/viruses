# %%
import csv 
import pandas as pd
#read CSV files that contain pandemic data 
COVID_data = pd.read_csv("data_sets/COVID-19.csv") 
COVID_data
COVID_data.loc[COVID_data['iso_code'] == 'EGY']

#5 countries of focus
#AP= US, Australia    ZL= China, Russia  JB= UK, EGY

#Clean COVID-19 DataFrame and extract data based on location, date, total_cases, and total_deaths
#Create new COVID-19 DataFrame
#Multiple Line graph for date and total_cases for each country
#Line graph for date and total deaths for each country
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 8070      EGY    Africa    Egypt  2019-12-31          0.0        0.0
# 8071      EGY    Africa    Egypt  2020-01-01          0.0        0.0
# 8072      EGY    Africa    Egypt  2020-01-02          0.0        0.0
# 8073      EGY    Africa    Egypt  2020-01-03          0.0        0.0
# 8074      EGY    Africa    Egypt  2020-01-04          0.0        0.0
# ...       ...       ...      ...         ...          ...        ...
# 8255      EGY    Africa    Egypt  2020-07-07      76222.0      969.0
# 8256      EGY    Africa    Egypt  2020-07-08      77279.0     1057.0
# 8257      EGY    Africa    Egypt  2020-07-09      78304.0     1025.0
# 8258      EGY    Africa    Egypt  2020-07-10      79254.0      950.0
# 8259      EGY    Africa    Egypt  2020-07-11      80235.0      981.0
#
#       total_deaths  new_deaths  total_cases_per_million  \
# 8070           0.0         0.0                    0.000
# 8071           0.0         0.0                    0.000
# 8072           0.0         0.0                    0.000
# 8073           0.0         0.0                    0.000
# 8074           0.0         0.0                    0.000
# ...            ...         ...                      ...
# 8255        3422.0        79.0                  744.833
# 8256        3489.0        67.0                  755.161
# 8257        3564.0        75.0                  765.178
# 8258        3617.0        53.0                  774.461
# 8259        3702.0        85.0                  784.047
#
#       new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
# 8070                  0.000  ...          2.891       10550.206
# 8071                  0.000  ...          2.891       10550.206
# 8072                  0.000  ...          2.891       10550.206
# 8073                  0.000  ...          2.891       10550.206
# 8074                  0.000  ...          2.891       10550.206
# ...                     ...  ...            ...             ...
# 8255                  9.469  ...          2.891       10550.206
# 8256                 10.329  ...          2.891       10550.206
# 8257                 10.016  ...          2.891       10550.206
# 8258                  9.283  ...          2.891       10550.206
# 8259                  9.586  ...          2.891       10550.206
#
#       extreme_poverty  cvd_death_rate  diabetes_prevalence  female_smokers  \
# 8070              1.3         525.432                17.31             0.2
# 8071              1.3         525.432                17.31             0.2
# 8072              1.3         525.432                17.31             0.2
# 8073              1.3         525.432                17.31             0.2
# 8074              1.3         525.432                17.31             0.2
# ...               ...             ...                  ...             ...
# 8255              1.3         525.432                17.31             0.2
# 8256              1.3         525.432                17.31             0.2
# 8257              1.3         525.432                17.31             0.2
# 8258              1.3         525.432                17.31             0.2
# 8259              1.3         525.432                17.31             0.2
#
#       male_smokers  handwashing_facilities hospital_beds_per_thousand  \
# 8070          50.1                  89.827                        1.6
# 8071          50.1                  89.827                        1.6
# 8072          50.1                  89.827                        1.6
# 8073          50.1                  89.827                        1.6
# 8074          50.1                  89.827                        1.6
# ...            ...                     ...                        ...
# 8255          50.1                  89.827                        1.6
# 8256          50.1                  89.827                        1.6
# 8257          50.1                  89.827                        1.6
# 8258          50.1                  89.827                        1.6
# 8259          50.1                  89.827                        1.6
#
#       life_expectancy
# 8070            71.99
# 8071            71.99
# 8072            71.99
# 8073            71.99
# 8074            71.99
# ...               ...
# 8255            71.99
# 8256            71.99
# 8257            71.99
# 8258            71.99
# 8259            71.99
#
# [190 rows x 34 columns]

# %%
#LOCATING COVID DATA
#COVID_data.loc[COVID_data['iso_code'] == 'USA']
# COVID_data.loc[COVID_data['iso_code'] == 'AUS']
# COVID_data.loc[COVID_data['iso_code'] == 'MEX']
#COVID_data.loc[COVID_data['iso_code'] == 'UK']#No UK
#COVID_data.loc[COVID_data['iso_code'] == 'CHL'] 
#COVID_data.loc[COVID_data['iso_code'] == 'CAN']

# %%
##COVID-19 Do more cases= more deaths?
# plot scatter plot and linear regression for each country Cases x, Deaths y

# %%
#Clean H1N1 DataFrame and extract data based on location, date, total_cases, and total_deaths
#Create new H1N1 DataFrame
# Line graph for Update Time and Cases for each country
#Line graph for date and total Deaths for each country

# %%
##H1N1 Do more cases= more deaths?
# plot scatter plot and linear regression for each country Cases x, Deaths y

# %%
## Which country has the most cases for each pandemic?

# %%
##Hypothesis: Covid-19 will have a higher transmition rate than H1N1. 

# Independent T-test

# %%
#Do more cases= more deaths based on age
