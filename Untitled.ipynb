# %%
import csv 
import pandas as pd
data = pd.read_csv("data_sets/H2N2.csv") 
data
# Out:
#                 Country  1957 pop. size (M)  \
# 0                   NaN                 NaN
# 1                 Egypt               10.80
# 2       England & Wales               44.91
# 3        United Kingdom               51.43
# 4               Denmark                4.49
# 5           Netherlands               11.03
# 6               Iceland                0.16
# 7               Ireland                2.89
# 8                Norway                3.49
# 9               Belgium                8.99
# 10             Scotland                5.12
# 11                  USA              170.37
# 12     Northern Ireland                1.40
# 13                Italy               49.18
# 14            Australia                9.64
# 15               Israel                1.72
# 16       Czechoslovakia               13.36
# 17               Canada               16.59
# 18          West Berlin                2.22
# 19          Switzerland                5.13
# ...
